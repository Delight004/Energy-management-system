# %%
import numpy as np
import pandas as pd

# %%
PV_dataset = pd.read_csv('PV_Dataset.csv')

# %%
PV_dataset.head()
# Out:
#             time  PV power  Direct-in-plane  Sun Height  Air Temperature  \
# 0  20200101:0011       0.0              0.0         0.0             5.77
# 1  20200101:0111       0.0              0.0         0.0             5.78
# 2  20200101:0211       0.0              0.0         0.0             5.45
# 3  20200101:0311       0.0              0.0         0.0             4.76
# 4  20200101:0411       0.0              0.0         0.0             4.23
#
#    Wind speed
# 0        0.62
# 1        1.10
# 2        1.45
# 3        1.79
# 4        1.93

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# Spliting time column into Years, Months, Days and time

# %%
PV_dataset['year'] = PV_dataset['time'].str[:4]

# %%
PV_dataset.head()
# Out:
#             time  PV power  Direct-in-plane  Sun Height  Air Temperature  \
# 0  20200101:0011       0.0              0.0         0.0             5.77
# 1  20200101:0111       0.0              0.0         0.0             5.78
# 2  20200101:0211       0.0              0.0         0.0             5.45
# 3  20200101:0311       0.0              0.0         0.0             4.76
# 4  20200101:0411       0.0              0.0         0.0             4.23
#
#    Wind speed  year
# 0        0.62  2020
# 1        1.10  2020
# 2        1.45  2020
# 3        1.79  2020
# 4        1.93  2020

# %%
PV_dataset['month'] = PV_dataset['time'].str[4:6]
PV_dataset['day'] = PV_dataset['time'].str[6:8]
PV_dataset['hour_minute'] = PV_dataset['time'].str[9:]

# %%
PV_dataset.head()
# Out:
#             time  PV power  Direct-in-plane  Sun Height  Air Temperature  \
# 0  20200101:0011       0.0              0.0         0.0             5.77
# 1  20200101:0111       0.0              0.0         0.0             5.78
# 2  20200101:0211       0.0              0.0         0.0             5.45
# 3  20200101:0311       0.0              0.0         0.0             4.76
# 4  20200101:0411       0.0              0.0         0.0             4.23
#
#    Wind speed  year month day hour_minute
# 0        0.62  2020    01  01        0011
# 1        1.10  2020    01  01        0111
# 2        1.45  2020    01  01        0211
# 3        1.79  2020    01  01        0311
# 4        1.93  2020    01  01        0411

# %%
PV_dataset = PV_dataset.drop(columns ='time', axis =1)

# %%
PV_dataset.head()
# Out:
#    PV power  Direct-in-plane  Sun Height  Air Temperature  Wind speed  year  \
# 0       0.0              0.0         0.0             5.77        0.62  2020
# 1       0.0              0.0         0.0             5.78        1.10  2020
# 2       0.0              0.0         0.0             5.45        1.45  2020
# 3       0.0              0.0         0.0             4.76        1.79  2020
# 4       0.0              0.0         0.0             4.23        1.93  2020
#
#   month day hour_minute
# 0    01  01        0011
# 1    01  01        0111
# 2    01  01        0211
# 3    01  01        0311
# 4    01  01        0411

# %%
PV_dataset.shape
# Out:
# (8788, 9)

# %%
PV_dataset['hour_minute'] = PV_dataset['hour_minute'].str[:2]

# %%
PV_dataset.head()
# Out:
#    PV power  Direct-in-plane  Sun Height  Air Temperature  Wind speed  year  \
# 0       0.0              0.0         0.0             5.77        0.62  2020
# 1       0.0              0.0         0.0             5.78        1.10  2020
# 2       0.0              0.0         0.0             5.45        1.45  2020
# 3       0.0              0.0         0.0             4.76        1.79  2020
# 4       0.0              0.0         0.0             4.23        1.93  2020
#
#   month day hour_minute
# 0    01  01          00
# 1    01  01          01
# 2    01  01          02
# 3    01  01          03
# 4    01  01          04

# %%
PV_dataset.columns
# Out:
# Index(['PV power', 'Direct-in-plane', 'Sun Height', 'Air Temperature',
#        'Wind speed', 'year', 'month', 'day', 'hour_minute'],
#       dtype='object')

# %%
# PV_dataset.to_csv('PV_dataset1.csv', index= False)

# %%
PV_dataset = PV_dataset[(PV_dataset[['PV power', 'Direct-in-plane', 'Sun Height']] != 0).any(axis=1)]

# %%
PV_dataset.head()
# Out:
#     PV power  Direct-in-plane  Sun Height  Air Temperature  Wind speed  year  \
# 9       0.00             0.83        2.15             4.12        2.07  2020
# 10      4.47            14.37        7.91             4.48        2.07  2020
# 11      9.70            22.45       11.94             5.47        2.07  2020
# 12     49.28            72.31       13.94             6.16        2.07  2020
# 13    108.50           139.14       13.73             6.93        2.55  2020
#
#    month day hour_minute
# 9     01  01          09
# 10    01  01          10
# 11    01  01          11
# 12    01  01          12
# 13    01  01          13

# %%
PV_dataset.shape
# Out:
# (4284, 9)

# %%
PV_dataset.describe()
# Out:
#           PV power  Direct-in-plane   Sun Height  Air Temperature   Wind speed
# count  4284.000000      4284.000000  4284.000000      4284.000000  4284.000000
# mean    214.659526       268.723450    25.511391        11.612495     3.527453
# std     214.262822       257.827156    16.071708         4.652839     1.739556
# min       0.000000         0.830000     1.510000        -3.020000     0.070000
# 25%      42.482500        67.300000    12.337500         8.150000     2.210000
# 50%     137.235000       178.735000    22.360000        11.715000     3.450000
# 75%     339.137500       410.712500    38.170000        15.010000     4.620000
# max     911.830000      1106.720000    60.270000        23.810000    10.210000

# %%
PV_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4284 entries, 9 to 8775
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PV power         4284 non-null   float64
#  1   Direct-in-plane  4284 non-null   float64
#  2   Sun Height       4284 non-null   float64
#  3   Air Temperature  4284 non-null   float64
#  4   Wind speed       4284 non-null   float64
#  5   year             4284 non-null   object
#  6   month            4284 non-null   object
#  7   day              4284 non-null   object
#  8   hour_minute      4284 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 334.7+ KB

# %%
PV_dataset['month'] = PV_dataset['month'].astype(int)
PV_dataset['day'] = PV_dataset['day'].astype(int)
PV_dataset['hour_minute'] = PV_dataset['hour_minute'].astype(int)

# %%
PV_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4284 entries, 9 to 8775
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PV power         4284 non-null   float64
#  1   Direct-in-plane  4284 non-null   float64
#  2   Sun Height       4284 non-null   float64
#  3   Air Temperature  4284 non-null   float64
#  4   Wind speed       4284 non-null   float64
#  5   year             4284 non-null   object
#  6   month            4284 non-null   int32
#  7   day              4284 non-null   int32
#  8   hour_minute      4284 non-null   int32
# dtypes: float64(5), int32(3), object(1)
# memory usage: 284.5+ KB

# %%
PV_dataset.isnull().sum()
# Out:
# PV power           0
# Direct-in-plane    0
# Sun Height         0
# Air Temperature    0
# Wind speed         0
# year               0
# month              0
# day                0
# hour_minute        0
# dtype: int64

# %%
PV_dataset = PV_dataset.drop(columns ='year', axis =1)

# %%
PV_dataset.to_csv('PV_dataset3.csv', index= False)

# %% [markdown]
# DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Correlation Matrix Heatmap

# %%
plt.figure(figsize = (6,6))
detaset_corr = PV_dataset.corr()
sns.heatmap(detaset_corr, cbar= True, square= True, fmt= '.3f', annot =True, annot_kws= {'size':8}, cmap= 'Reds')
plt.show()

# %% [markdown]
# Primary Influencer: The most significant factor impacting PV power generation is direct-in-plane radiation, showing that direct sunlight on the panel is crucial for power output.
#
# Secondary Influencer: Sun Height moderately affects PV power, likely because it influences the amount of sunlight reaching the PV panel and it also depends on the hours of the day
#
# Minimal Influence: Air temperature, wind speed, and temporal variables (year, month, day, hour) have little to no impact on PV power output. Higher temperatures might slightly increase power generation due to thermal effects, but extreme heat can reduce PV efficiency.

# %% [markdown]
# Time Series Plot of PV Power

# %%
plt.figure(figsize=(6, 6))
sns.lineplot(data=PV_dataset, x='hour_minute', y='PV power', label='PV Power', color='orange')
plt.xlabel('Time')
plt.ylabel('PV Power')
plt.title('PV Power Over Time')
plt.legend()
plt.show()

# %% [markdown]
# Scatter Plot of Direct-in-plane vs. PV Power

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=PV_dataset, x='Direct-in-plane', y='PV power', color='orange', alpha=0.6)
plt.xlabel('Direct-in-plane')
plt.ylabel('PV Power')
plt.title('Scatter Plot of Direct-in-plane vs. PV Power')
plt.show()

# %% [markdown]
# Heatmap of PV Power by Hour and Day

# %%
heatmap_data = PV_dataset.pivot_table(index='month', columns='hour_minute', values='PV power', aggfunc='mean')

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='YlOrRd', cbar_kws={'label': 'PV Power'})
plt.xlabel('Hour-Minute')
plt.ylabel('Month')
plt.title('Heatmap of PV Power by Hour and Day')
plt.show()

# %% [markdown]
# Sun Height vs. PV Power Scatter Plot

# %%
plt.figure(figsize=(10, 6))
plt.scatter(PV_dataset['Sun Height'], PV_dataset['PV power'], alpha=0.6, color='orange')
plt.xlabel('Sun Height')
plt.ylabel('PV Power')
plt.title('Scatter Plot of Sun Height vs. PV Power')
plt.show()

# %% [markdown]
# SPLITING DATASET INTO VARIABLES AND TARGET

# %%
X = PV_dataset.drop(columns = ['PV power'], axis= 1)
Y = PV_dataset['PV power']

# %%
X.head()
# Out:
#     Direct-in-plane  Sun Height  Air Temperature  Wind speed  month  day  \
# 9              0.83        2.15             4.12        2.07      1    1
# 10            14.37        7.91             4.48        2.07      1    1
# 11            22.45       11.94             5.47        2.07      1    1
# 12            72.31       13.94             6.16        2.07      1    1
# 13           139.14       13.73             6.93        2.55      1    1
#
#     hour_minute
# 9             9
# 10           10
# 11           11
# 12           12
# 13           13

# %%
Y.head()
# Out:
# 9       0.00
# 10      4.47
# 11      9.70
# 12     49.28
# 13    108.50
# Name: PV power, dtype: float64

# %% [markdown]
# SPLITING DATASET INTO TRAINING AND TEST DATA

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2, random_state= 2)

# %%
X_train.shape, X_test.shape, Y_train.shape
# Out:
# ((3427, 7), (857, 7), (3427,))

# %%
#!pip install xgboost lightgbm

# %% [markdown]
# MODEL TRAINING

# %%
# libraries for training model
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from lightgbm import LGBMRegressor

# %%
# libraries for model accuracy
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# MODEL TRAINING USING RANDOM FOREST REGRESSOR

# %%
model_rf = RandomForestRegressor()
model_rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
test_data_prediction = model_rf.predict(X_test)

# %% [markdown]
# Model Accuracy

# %%
test_data_r2 = r2_score(test_data_prediction, Y_test)
test_data_MAE = mean_absolute_error(test_data_prediction, Y_test)
test_data_MSE = mean_squared_error(test_data_prediction, Y_test)
print(f'The test data r2 score: {test_data_r2}')
print(f'The test data MAE score: {test_data_MAE}')
print(f'The test data MSE score: {test_data_MSE}')
# Out:
# The test data r2 score: 0.9994632829311983
# The test data MAE score: 2.7485952158693014
# The test data MSE score: 24.917552206732637

# %% [markdown]
# Model Optimization

# %%
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10, 20],
     'min_samples_split': [2, 5], 
}

# %%
grid_search = GridSearchCV(estimator=model_rf, param_grid=param_grid, cv=5,  n_jobs=-1, verbose=2, scoring='accuracy')

# %%
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              scoring='accuracy', verbose=2)

# %%
best_params = grid_search.best_params_

# %%
best_model_rf = grid_search.best_estimator_

# %%
test_prediction = best_model_rf.predict(X_test)
test_data_r2 = r2_score(test_prediction, Y_test)
test_data_MAE = mean_absolute_error(test_prediction, Y_test)
test_data_MSE = mean_squared_error(test_prediction, Y_test)
print(f'The testing data r2 score: {test_data_r2}')
print(f'The testing data MAE score: {test_data_MAE}')
print(f'The testing data MSE score: {test_data_MSE}')
# Out:
# The testing data r2 score: 0.9994235196689834
# The testing data MAE score: 2.7877603267211244
# The testing data MSE score: 26.73472037661618

# %%
Y_test_list= list(Y_test)

# %%
plt.figure(figsize=(10, 6))
plt.plot(Y_test_list, label='Actual PV Power')
plt.plot(test_prediction, label='Predicted PV Power')
plt.xlabel('Sample Index')
plt.ylabel('PV Power')
plt.title('Actual vs Predicted PV Power')
plt.legend()
plt.show()

# %% [markdown]
# MODEL TRAINING USING SUPPORT VECTOR MACHINE

# %%
model_svm = SVR()
model_svm.fit(X_train, Y_train)
# Out:
# SVR()

# %%
X_test_prediction = model_svm.predict(X_test)

# %% [markdown]
# Model Accuracy

# %%
test_data_r2 = r2_score(X_test_prediction, Y_test)
test_data_MAE = mean_absolute_error(X_test_prediction, Y_test)
test_data_MSE = mean_squared_error(X_test_prediction, Y_test)
print(f'The testing data r2 score: {test_data_r2}')
print(f'The testing data MAE score: {test_data_MAE}')
print(f'The testing data MSE score: {test_data_MSE}')
# Out:
# The testing data r2 score: 0.9487489980987205
# The testing data MAE score: 15.88636929875181
# The testing data MSE score: 1885.3723994214622

# %% [markdown]
# Model Optimization

# %%
param_grid = {
    'C': [0.1, 1],                  # Regularization parameter
    'kernel': ['linear', 'rbf'],      # Kernel type
    'epsilon': [0.01, 0.1]          # Epsilon parameter for the loss function
}

# %%
grid_search = GridSearchCV(estimator=model_svm, param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=-1, verbose=2)

# %%
grid_search.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1], 'epsilon': [0.01, 0.1],
#                          'kernel': ['linear', 'rbf']},
#              scoring='accuracy', verbose=2)

# %%
best_parans = grid_search.best_params_

# %%
best_model_svr = grid_search.best_estimator_

# %%
test_accuracy = best_model_svr.predict(X_test)
test_data_r2 = r2_score(test_prediction, Y_test)
test_data_MAE = mean_absolute_error(test_prediction, Y_test)
test_data_MSE = mean_squared_error(test_prediction, Y_test)
print(f'The testing data r2 score: {test_data_r2}')
print(f'The testing data MAE score: {test_data_MAE}')
print(f'The testing data MSE score: {test_data_MSE}')
# Out:
# The testing data r2 score: 0.9994235196689834
# The testing data MAE score: 2.7877603267211244
# The testing data MSE score: 26.73472037661618

# %%
Y_test_list = list(Y_test)

# %%
plt.figure(figsize=(10, 6))
plt.plot(Y_test_list, label='Actual PV Power')
plt.plot(test_prediction, label='Predicted PV Power')
plt.xlabel('Sample Index')
plt.ylabel('PV Power')
plt.title('Actual vs Predicted PV Power')
plt.legend()
plt.show()

# %% [markdown]
# MODEL TRAINING USING XGBREGRESSOR

# %%
model_xgb = XGBRegressor()
model_xgb.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
test_prediction = model_xgb.predict(X_test)
train_predition = model_xgb.predict(X_train)

# %% [markdown]
# Model Accuracy

# %%
test_data_r2 = r2_score(test_prediction, Y_test)
test_data_MAE = mean_absolute_error(test_prediction, Y_test)
test_data_MSE = mean_squared_error(test_prediction, Y_test)
print(f'The testing data r2 score: {test_data_r2}')
print(f'The testing data MAE score: {test_data_MAE}')
print(f'The testing data MSE score: {test_data_MSE}')
# Out:
# The testing data r2 score: 0.9996295836606618
# The testing data MAE score: 2.357671398223055
# The testing data MSE score: 17.147145834346997

# %%
train_data_r2 = r2_score(train_predition, Y_train)
train_data_MAE = mean_absolute_error(train_predition, Y_train)
train_data_MSE = mean_squared_error(train_predition, Y_train)
print(f'The testing data r2 score: {train_data_r2}')
print(f'The testing data MAE score: {train_data_MAE}')
print(f'The testing data MSE score: {train_data_MSE}')
# Out:
# The testing data r2 score: 0.9999850724287485
# The testing data MAE score: 0.591891804088483
# The testing data MSE score: 0.6821825320979902

# %% [markdown]
# Model Optimization

# %%
param_grid = {
    'n_estimators': [100, 200, 500],
    'learning_rate': [0.01, 0.05],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0]
}

# %%
grid_search = GridSearchCV(estimator=model_xgb, param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=-1, verbose=2)

# %%
grid_search.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05],
#                          'min_child_weight': [1, 3, 5],
#                          'n_estimators': [100, 200, 500],
#                          'subsample': [0.6, 0.8, 1.0]},
#              scoring='accuracy', verbose=2)

# %%
best_param = grid_search.best_params_

# %%
best_model_xgb = grid_search.best_estimator_

# %%
test_prediction = best_model_xgb.predict(X_test)

# %%
test_data_r2 = r2_score(test_prediction, Y_test)
test_data_MAE = mean_absolute_error(test_prediction, Y_test)
test_data_MSE = mean_squared_error(test_prediction, Y_test)
print(f'The testing data r2 score: {test_data_r2}')
print(f'The testing data MAE score: {test_data_MAE}')
print(f'The testing data MSE score: {test_data_MSE}')
# Out:
# The testing data r2 score: 0.6377060347631502
# The testing data MAE score: 65.03356341581222
# The testing data MSE score: 6622.369178604009

# %%
Y_test_list = list(Y_test)

# %%
plt.figure(figsize=(10, 6))
plt.plot(Y_test_list, label='Actual PV Power')
plt.plot(test_prediction, label='Predicted PV Power')
plt.xlabel('Sample Index')
plt.ylabel('PV Power')
plt.title('Actual vs Predicted PV Power')
plt.legend()
plt.show()

# %% [markdown]
# DEEP LEARN (ARTIFICIAL NEURAL NETWORK)

# %%
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras

# %%
model_ANN = keras.Sequential([
    keras.layers.Flatten(input_shape = (X_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear
100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.9118 - mae: 3.5396 - val_loss: 48.3669 - val_mae: 5.7615
# Epoch 62/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.6673 - mae: 3.5220 - val_loss: 49.5120 - val_mae: 5.8386
# Epoch 63/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 29.1038 - mae: 3.4789 - val_loss: 48.8359 - val_mae: 5.7672
# Epoch 64/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.2916 - mae: 3.4923 - val_loss: 48.7024 - val_mae: 5.7646
# Epoch 65/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.0715 - mae: 3.4770 - val_loss: 46.7289 - val_mae: 5.6491
# Epoch 66/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.1725 - mae: 3.4722 - val_loss: 47.1073 - val_mae: 5.6702
# Epoch 67/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.6087 - mae: 3.4432 - val_loss: 46.7421 - val_mae: 5.6775
# Epoch 68/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.6093 - mae: 3.4459 - val_loss: 46.9754 - val_mae: 5.6760
# Epoch 69/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.6635 - mae: 3.4534 - val_loss: 47.1089 - val_mae: 5.6987
# Epoch 70/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.5288 - mae: 3.4351 - val_loss: 45.6054 - val_mae: 5.5951
# Epoch 71/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.9730 - mae: 3.4066 - val_loss: 46.8389 - val_mae: 5.6754
# Epoch 72/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.3072 - mae: 3.4247 - val_loss: 45.5673 - val_mae: 5.5954
# Epoch 73/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.0054 - mae: 3.4098 - val_loss: 45.4264 - val_mae: 5.5739
# Epoch 74/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.1789 - mae: 3.4161 - val_loss: 45.6410 - val_mae: 5.5887
# Epoch 75/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.7095 - mae: 3.3835 - val_loss: 43.2751 - val_mae: 5.4347
# Epoch 76/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.5782 - mae: 3.3673 - val_loss: 43.6660 - val_mae: 5.4759
# Epoch 77/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27.6653 - mae: 3.3767 - val_loss: 42.5871 - val_mae: 5.3903
# Epoch 78/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.3411 - mae: 3.3484 - val_loss: 42.6261 - val_mae: 5.3923
# Epoch 79/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.3109 - mae: 3.3476 - val_loss: 42.0507 - val_mae: 5.3633
# Epoch 80/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.2112 - mae: 3.3423 - val_loss: 43.4483 - val_mae: 5.4558
# Epoch 81/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.2417 - mae: 3.3461 - val_loss: 42.2731 - val_mae: 5.3749
# Epoch 82/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.9814 - mae: 3.3228 - val_loss: 41.8320 - val_mae: 5.3417
# Epoch 83/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.9642 - mae: 3.3300 - val_loss: 41.4508 - val_mae: 5.3321
# Epoch 84/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5443 - mae: 3.3049 - val_loss: 42.0769 - val_mae: 5.3561
# Epoch 85/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.8243 - mae: 3.3150 - val_loss: 43.3076 - val_mae: 5.4444
# Epoch 86/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27.3224 - mae: 3.3572 - val_loss: 43.6360 - val_mae: 5.4678
# Epoch 87/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.2218 - mae: 3.3392 - val_loss: 42.4410 - val_mae: 5.3910
# Epoch 88/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.2348 - mae: 3.3539 - val_loss: 42.4704 - val_mae: 5.3865
# Epoch 89/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.0885 - mae: 3.3295 - val_loss: 41.4318 - val_mae: 5.3264
# Epoch 90/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.9574 - mae: 3.3354 - val_loss: 41.1362 - val_mae: 5.2955
# Epoch 91/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.8159 - mae: 3.3176 - val_loss: 41.8237 - val_mae: 5.3548
# Epoch 92/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.8304 - mae: 3.3221 - val_loss: 41.4572 - val_mae: 5.3052
# Epoch 93/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26.9037 - mae: 3.3290 - val_loss: 40.7790 - val_mae: 5.2706
# Epoch 94/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.6695 - mae: 3.3099 - val_loss: 41.2984 - val_mae: 5.2927
# Epoch 95/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5177 - mae: 3.2964 - val_loss: 41.2015 - val_mae: 5.3292
# Epoch 96/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.6141 - mae: 3.3160 - val_loss: 41.2160 - val_mae: 5.3086
# Epoch 97/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5332 - mae: 3.3035 - val_loss: 43.2166 - val_mae: 5.4619
# Epoch 98/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.9055 - mae: 3.3369 - val_loss: 39.8220 - val_mae: 5.1878
# Epoch 99/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.1716 - mae: 3.2688 - val_loss: 41.7947 - val_mae: 5.3492
# Epoch 100/100
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5138 - mae: 3.3024 - val_loss: 39.5097 - val_mae: 5.1628

# %% [markdown]
# Model Accuracy

# %%
loss, accuracy = model_ANN.evaluate(X_test, Y_test)
print(f'The accuracy of the model is {accuracy} and loss is {loss}')
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.7095 - mae: 5.0472
# The accuracy of the model is 5.116757869720459 and loss is 39.4965934753418

# %%
test_prediction = model_ANN.predict(X_test)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
test_data_r2 = r2_score(test_prediction, Y_test)
test_data_MAE = mean_absolute_error(test_prediction, Y_test)
test_data_MSE = mean_squared_error(test_prediction, Y_test)
print(f'The testing data r2 score: {test_data_r2}')
print(f'The testing data MAE score: {test_data_MAE}')
print(f'The testing data MSE score: {test_data_MSE}')
# Out:
# The testing data r2 score: 0.999138150386522
# The testing data MAE score: 5.1167571719468965
# The testing data MSE score: 39.49659721463826

# %%
Y_test_list = list(Y_test)

# %%
plt.figure(figsize=(10, 6))
plt.plot(Y_test_list, label='Actual PV Power')
plt.plot(test_prediction, label='Predicted PV Power')
plt.xlabel('Sample Index')
plt.ylabel('PV Power')
plt.title('Actual vs Predicted PV Power')
plt.legend()
plt.show()

# %% [markdown]
# RESULT

# %%
test_result = {
    'Model' : ['Random Forest', 'Support Vector Mechine', 'XGB Regressor', 'ANN'],
    'r2 score': [0.9994235196689834, 0.9994235196689834, 0.6377060347631502, 0.999138150386522],
    'MAE score': [2.7877603267211244, 2.7877603267211244, 65.03356341581222, 5.1167571719468965], 
    'MSE score': [26.73472037661618, 26.73472037661618, 6622.369178604009, 39.49659721463826],
}

# %%
test_result = pd.DataFrame(test_result)

# %%
test_result
# Out:
#                     Model  r2 score  MAE score    MSE score
# 0           Random Forest  0.999424   2.787760    26.734720
# 1  Support Vector Mechine  0.999424   2.787760    26.734720
# 2           XGB Regressor  0.637706  65.033563  6622.369179
# 3                     ANN  0.999138   5.116757    39.496597

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='Model', y='r2 score', data=test_result)
plt.title('R Square Test Result')
plt.xlabel('Model')
plt.ylabel('R Square')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# MODEL PREDICTIVE SYSTEM

# %%
input_dataset = (516.46,12.07,4.98,2.14,1,3,11)
input_dataset_asarray = np.asarray(input_dataset)
input_data_reshape = input_dataset_asarray.reshape(1,-1)
prediction = best_model_rf.predict(input_data_reshape)
print(f'The PV Power output is {prediction}')
# Out:
# The PV Power output is [446.1736]
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
